# %% [markdown]
# # Notebook that allows to open single hdf5 file and perform routine operation
#
# You can plot PSDs, calculate mode temperatures, calculate strain sensitivities, convert into strain, filter the data, inject fake signals to test the filtering, generate a pickle with event catalogue upon filtering

# %% [markdown]
# ## Imports

# %%
import h5py
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import os
from os import listdir
from scipy import signal
from scipy.signal import welch, csd
from scipy.signal import find_peaks
import lmfit
from scipy.fft import fft, fftfreq
import nexusformat.nexus as nx
import scipy.constants
from lmfit.models import LorentzianModel, ConstantModel
import sys
import os

# %% [markdown]
# ## Opening file and retrieving data
# Make sure you modify appropriately the folders here, where all data will be retrieved from

# %%
run = 2
subrun = 58
NFFT = 2**13

#filepath = '/home/leo_maria/Desktop/UWA/MAGE/MAGE4/run' + str(run) + '/run' + str(run) + '-' + str(subrun) + '.hdf5' # for run !=2 # where your hdf5 files are
filepath = '/home/leo_maria/Desktop/UWA/MAGE/MAGE4/run' + str(run) + '/run' + str(run) + '--' + str(subrun) + '.hdf5'  #for run 2

calibration_folder = '/home/leo_maria/Desktop/UWA/MAGE/MAGE4/calibration'  # where your calibration data is

# Specify the absolute path to the 'libraries' directory, where Analysis_functions is
library_path = '/home/leo_maria/Desktop/UWA/MAGE/libraries/'  # Adjust this to the actual absolute path
sys.path.append(library_path)
import Analysis_functions

# %%
Ninputs, Nchannels, Nsamples, Fs, dt, fdemods, t_start = Analysis_functions.get_meta_data_from_first_file(filepath) 
iq = Analysis_functions.retrieve_IQ_td(filepath)
file_start = t_start + timedelta(seconds = subrun*Nsamples*dt)
freqs, Sx, Sy, Sr = Analysis_functions.psd_from_IQ_td(iq, Fs, NFFT=NFFT)
time = np.linspace(0, Nsamples*dt, Nsamples)

# %%
# Create subplots with 8 subplots per figure (2 rows and 4 columns)
fig, axes = plt.subplots(2, 4, figsize=(18, 12))  # Create a 2x4 grid of subplots
axes = axes.flatten()  # Flatten the 2D axes array for easy indexing

plot_idx = 0  # To index through the subplots
for ai in [0, 1]:
    for ch in range(Nchannels):
        # Ensure you don't exceed the number of available subplots (8 in this case)
        if plot_idx >= len(axes):
            plt.tight_layout()  # Adjust layout when max subplots reached
            plt.show()           # Show the current figure
            fig, axes = plt.subplots(2, 4, figsize=(18, 12))  # Create a new figure with 8 subplots
            axes = axes.flatten()  # Flatten the axes for easy indexing
            plot_idx = 0  # Reset plot index for new figure

        ax = axes[plot_idx]  # Select the current axis for plotting
        ax.plot(freqs[ai, ch, :], Sx[ai, ch, :])
        ax.set_xlabel('Freq [Hz]')
        ax.set_ylabel('PSD (V/rtHz)')
        ax.set_title(f'Ai {ai}  Channel {ch}')
        plot_idx += 1  # Move to the next subplot index

# Final display of the last figure if not already shown
plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

# %% [markdown]
# ## Fit of thermal peaks

# %%
# Try and fit 

f_res = np.zeros((Ninputs,Nchannels))
sigmas = np.zeros_like(f_res)
integrals = np.zeros_like(f_res)
Qs = np.zeros_like(f_res)
const = np.zeros_like(f_res)
const_maxima = np.zeros_like(f_res)
f_res_err = np.zeros((Ninputs,Nchannels))
sigmas_err = np.zeros_like(f_res)
Qs_err = np.zeros_like(f_res)
const_err = np.zeros_like(f_res)

for ai in range(Ninputs):
    for ch in range(Nchannels):
        f_res[ai,ch], sigmas[ai,ch], integrals[ai,ch], Qs[ai,ch], const[ai,ch], f_res_err[ai,ch], sigmas_err[ai,ch], Qs_err[ai,ch], const_err[ai,ch] = Analysis_functions.lorentzian_fit_thermalpeak_bis(Sx[ai,ch,:], freqs[ai,ch,:], fdemods[ai,ch], ai, ch, Plot=False, start=500, stop=1300)
        const_maxima[ai, ch] = integrals[ai, ch] / np.pi / sigmas[ai, ch] + const[ai, ch]

# %%
plt.figure(figsize=(10,8))
for ai in [0,1]:
    plt.scatter(x=f_res[ai,:],y=Qs[ai,:], label='AI ' + str(ai), marker='v', edgecolor='black', s=100)
    plt.legend()
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Q')

# %% [markdown]
# ## Calculating mode temperatures

# %%
# import calibration
from scipy.constants import k
def read_two_column_data(file_path):
    data = np.loadtxt(file_path)
    column_1 = data[:, 0]  # First column
    column_2 = data[:, 1]  # Second column
    return np.array([column_1, column_2])

Vphi = read_two_column_data(calibration_folder + '/Vphi_squids_quartz_order.txt')
Rbaw = read_two_column_data(calibration_folder + '/Rs_new.txt')
Lin = 400e-9
Min = np.array([1 / 0.49 / 1e-6, 1 / 0.517 / 1e-6])
temperatures = np.zeros((Ninputs, Nchannels))

# %%
for ai in [0,1]:
    temperatures[ai, :] = (Rbaw[ai, :]**2 + (2*np.pi *f_res[ai,:] * Lin)**2 ) / (4 * k * Rbaw[ai, :] * (2000 * Vphi[ai, :] * Min[ai])**2 ) * const_maxima[ai, :]
print(const_maxima)
# Out:
# [[5.075604e-12 8.636319e-13 1.057705e-12 ... 8.769011e-12 1.965843e-11
#   1.054766e-12]
#  [3.470049e-12 5.283301e-13 6.422744e-13 ... 2.078063e-12 3.917275e-12
#   1.359738e-12]]

# %%
# Example data (replace these with your actual data)
# Rbaw = np.array([[...], [...]])  # 2D array
# temperatures = np.array([[...], [...]])  # 2D array

fig, ax = plt.subplots(figsize=(8, 6))  # One axis for the plot
colors = ['blue', 'red']

# Plot both datasets for ai = 0 and ai = 1 on the same plot
for ai in [0, 1]:
    ax.scatter(Rbaw[ai, :], temperatures[ai, :], c=colors[ai], edgecolor='black', marker='v', s=80, label=f'AI {ai}')

# Set labels and title
ax.set_xlabel('Motional resistance (ohm)')
ax.set_ylabel('Temperature [K]')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_title('Temperature vs Motional Resistance')

# Add a legend to distinguish between ai = 0 and ai = 1
ax.legend()

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Estimation of strain sensitivity from mode temps / PSD
#
# Use the formula $$S_h^+ (\omega_{\lambda} ) = \frac{2 \sqrt{S_v(\omega_{\lambda})}}{\kappa_{\lambda} \omega_{\lambda} Q_{\lambda} R_{\lambda} h_0 \xi_{\lambda}}.$$
#
# That's from MAGE paper, apart from a factor 2 that must have been lost somewhere in the calculations. In the paper from PRD the facttor 2 is there.

# %%
def strain_sens(psd_VperrtHz, kappa, freq, Q, R, h, xi):
    return 2 * psd_VperrtHz / (kappa * 2*np.pi * freq * Q * R * h * xi)

feffective_mass = open(calibration_folder + '/Meff.txt')
mode_distributions = np.genfromtxt(feffective_mass, delimiter=',', skip_header=1)
meff = mode_distributions[:,1]
xi = mode_distributions[:,2]

kappa=np.zeros((Ninputs, Nchannels))
for ai in range(Ninputs):
    for ch in range(Nchannels):
        kappa[ai, ch] = np.sqrt(fdemods[ai,ch]*2*np.pi*meff[ch]/(Qs[ai,ch]*Rbaw[ai,ch]))

# %%
plt.figure(figsize=(10,6))
sensitivities = np.zeros((Ninputs, Nchannels))
for ai in range(Ninputs):
    for ch in range(Nchannels):
        sensitivities[ai,ch] = strain_sens(const_maxima[ai,ch], kappa[ai,ch], f_res[ai,ch], Qs[ai,ch], Rbaw[ai,ch], 1e-3, xi[ch] )
    plt.scatter(f_res[ai, :]/1e6, sensitivities[ai, :], label = 'AI ' + str(ai), marker = 'v', s = 70, color = colors[ai], edgecolor='black')
    plt.xlabel(' Freq [MHz]', fontsize=12)
    plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
    plt.legend(fontsize=14)
    plt.ylabel(r'Strain sensitivity [strain/$\sqrt{Hz}$]', fontsize=12)
    plt.tick_params(axis='both', which='both', labelsize=12)
    plt.xscale('log')
    plt.yscale('log')
    plt.title('MAGE samples')
    plt.legend()

# %%
# Projection for RAKON baw
# In first approx I can only change the Q and keep the rest all the same
# I only use the modes with m,p=0 bc they are the only ones I can compare with MAGE modes

rakon_freqs = np.array([5.167938e6, 5.689650e6, 9.464160e6, 9.741672e6, 8.593911e6, 16.218814e6])
rakon_Qs = np.array([5725443.0, 19880834.0, 58681143.0, 27908919.0, 23976187.0, 58537395.0])
rakon_indices = np.array([0, 3, 6, 8, 10, 15])

plt.figure(figsize=(10,7))
rakon_sensitivities = np.zeros(rakon_indices.size)
ai = 0
for integer, ch in enumerate(rakon_indices):
    rakon_sensitivities[integer] = strain_sens(const_maxima[ai,ch], kappa[ai,ch], f_res[ai,ch], rakon_Qs[integer], Rbaw[ai,ch], 1e-3, xi[ch] )
plt.scatter(f_res[ai, rakon_indices]/1e6, rakon_sensitivities, label = 'Rakon quartz', marker = 'v', s = 70, color = colors[ai], edgecolor='black')
plt.scatter(f_res[ai, rakon_indices]/1e6, sensitivities[ai,rakon_indices], label = 'BVA quartz ', marker = 'v', s = 70, color = colors[ai+1], edgecolor='black')

plt.xlabel(' Freq [MHz]', fontsize=12)
plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
plt.legend(fontsize=14)
plt.ylabel(r'Strain sensitivity [strain/$\sqrt{Hz}$]', fontsize=12)
plt.tick_params(axis='both', which='both', labelsize=12)
plt.xscale('log')
plt.yscale('log')
plt.title('Strain sensitivities comparison')
plt.legend()
print('Rakon', rakon_Qs)
print('MAGE samples', Qs[ai, rakon_indices])
plt.show()
for i in range(rakon_indices.size):
    print('freq: ', f_res[ai, rakon_indices[i]], '\t BVA ss: ', sensitivities[ai,rakon_indices[i]], '\t RAKON ss: ', rakon_sensitivities[i])
# Out:
# Rakon [ 5725443. 19880834. 58681143. 27908919. 23976187. 58537395.]
# MAGE samples [19079293.75936  22701194.285152 43876833.980793 43679887.812443
#  42279597.713493 98594470.384219]
# freq:  4993041.068036406 	 BVA ss:  7.644823369139442e-21 	 RAKON ss:  2.547537907516144e-20
# freq:  5505680.65409676 	 BVA ss:  7.753778148233351e-21 	 RAKON ss:  8.853754534996478e-21
# freq:  9152222.447697163 	 BVA ss:  1.6563266901862296e-20 	 RAKON ss:  1.2384620934063666e-20
# freq:  9453789.457312021 	 BVA ss:  9.431467011639963e-21 	 RAKON ss:  1.476106691825621e-20
# freq:  8297612.025926928 	 BVA ss:  1.4393878161458094e-20 	 RAKON ss:  2.5382158480974455e-20
# freq:  15734388.948251158 	 BVA ss:  5.33212087035988e-22 	 RAKON ss:  8.980885350941432e-22

# %% [markdown]
# ## Injecting a fake signal

# %%
# CHECK IF FILTERING MAKES SENSE
ai = 0
channel = 9
Rdat = np.sqrt(iq[ai, channel, 0, :]**2 + iq[ai, channel, 1, :]**2)

# Generate the template signal
signal, t_sig, tau = Analysis_functions.generate_template(ai, channel, f_res, Qs, Fs, dt, Nsamples)

# Pad and roll the signal
template_pad = Analysis_functions.pad_and_roll_signal(signal, Rdat)

# Add noise to the signal
h_inject, h_inject2, h_inject3 = Analysis_functions.add_noise_to_signal(template_pad, Rdat)

# Apply the optimal filter
SNR, dat_filt = Analysis_functions.optimal_filter(h_inject, signal, Fs, NFFT=1024)
SNR2, dat_filt2 = Analysis_functions.optimal_filter(h_inject2, signal, Fs, NFFT=1024)
SNR3, dat_filt3 = Analysis_functions.optimal_filter(h_inject3, signal, Fs, NFFT=1024)
plt.show()
# Plot the results
nn = 50000
span = 10000
Analysis_functions.plot_filtered_data(tn=np.linspace(0, Nsamples*dt, Nsamples), nn=nn, span=span, h_inject=h_inject, h_inject3=h_inject3, dat_filt=dat_filt, dat_filt3=dat_filt3)

# %%
# meshgrid with results for different values of tau
Ntemplates = 100
Span = 500
SNR_arr = np.zeros((Ntemplates, Span))
tau_vec = tau*np.logspace(-2,2,Ntemplates)
for i in range(Ntemplates):
    template = np.exp(-t_sig/(tau_vec[i]))
    SNR, dat_filt = Analysis_functions.optimal_filter(h_inject3, template, Fs, NFFT)
    SNR_arr[i,:] = SNR[nn-Span//2:nn+Span//2]

Analysis_functions.plot_snr_colormesh(SNR_arr, tau_vec, time, nn, Span, tau, Fs, NFFT)
plt.plot(tau_vec, SNR_arr[:,Span//2])
plt.xscale('log')
plt.xlabel('tau[s]')
plt.ylabel('Max SNR at signal arrival')
# Out:
# Text(0, 0.5, 'Max SNR at signal instant')

# %% [markdown]
# Seems to make sense now:
# you get maximized snr for the correct time constant

# %% [markdown]
# ## Filtering the data

# %% [markdown]
# ## Conversion into strain
#
# Calculated that:
# $\begin{equation}
#     u(\omega) = \frac{1}{M_{in}(-j\omega)\kappa_{\lambda}} \frac{1}{2000 V_{\Phi}(\omega)} V(\omega)
# \end{equation}$
# If I use $R(\omega)$ as $V_{\omega}$, the strain I get is a time series (after ifft) of amplitude of strain at frequency at $\omega_{\text signal}$.\
# Careful: $\omega$ here must be the high frequency (you need to add demodulation
# )

# %%
R=np.zeros_like(iq[:,:,0,:])
kappa=np.zeros((Ninputs, Nchannels))
strain = np.zeros_like(R)

meff = Analysis_functions.get_eff_mass('/home/leo_maria/Desktop/UWA/MAGE/MAGE4/calibration/Meff.txt')

for ai in range(Ninputs):
    for ch in range(Nchannels):
        R[ai,ch,:] = np.sqrt(iq[ai, ch, 0, :]**2 + iq[ai,ch,1,:]**2)
        kappa[ai, ch] = np.sqrt(fdemods[ai,ch]*2*np.pi*meff[ch]/(Qs[ai,ch]*Rbaw[ai,ch]))
        strain[ai,ch] = Analysis_functions.R_to_strain(R[ai,ch,:], Fs, fdemods[ai,ch], Vphi[ai,ch], Min[ai], kappa[ai,ch])

plt.plot(time, strain[0,2])

# %% [markdown]
# ### Filter

# %%
tau=np.zeros((Ninputs,Nchannels))
tau = Qs /np.pi / f_res # Decay constant, assumed formula


SNR, filtered_strain, event_catalogue = Analysis_functions.filter_strain_data_one_file(strain, tau, Fs, NFFT, file_start, fdemods, subrun)
# Out:
# /home/leo_maria/Desktop/UWA/MAGE/libraries/Analysis_functions.py:549: ComplexWarning: Casting complex values to real discards the imaginary part
#   SNR[ai,ch], filtered_strain[ai,ch] = optimal_filter(strain[ai,ch], template, Fs, NFFT)
# 1.52, 1.78, 1.43
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 1.61, 1.61, 1.85
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 2.15, 1.99, 2.07
# 1.90, 2.01, 1.73
# Transiently divergent feature detected of SNR 1.90, performing quality cut
# 1.50, 1.78, 1.70
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 2.04, 2.29, 1.75
# Transiently divergent feature detected of SNR 2.04, performing quality cut
# 1.28, 1.56, 1.50
# Transiently divergent feature detected of SNR 1.28, performing quality cut
# 0.87, 1.53, 2.74
# Transiently divergent feature detected of SNR 0.87, performing quality cut
# 1.24, 1.92, 2.59
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.54, 1.82, 1.48
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 1.38, 1.76, 1.61
# Transiently divergent feature detected of SNR 1.38, performing quality cut
# 1.11, 1.32, 1.50
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 0.74, 0.97, 1.51
# Transiently divergent feature detected of SNR 0.74, performing quality cut
# 1.10, 1.93, 2.72
# Transiently divergent feature detected of SNR 1.10, performing quality cut
# 0.92, 1.71, 1.68
# Transiently divergent feature detected of SNR 0.92, performing quality cut
# 0.86, 0.99, 1.42
# Transiently divergent feature detected of SNR 0.86, performing quality cut
# 1.24, 1.91, 2.14
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.06, 1.32, 1.48
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 0.78, 1.05, 1.87
# Transiently divergent feature detected of SNR 0.78, performing quality cut
# 0.86, 1.51, 2.37
# Transiently divergent feature detected of SNR 0.86, performing quality cut
# 1.47, 1.82, 1.72
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 1.55, 2.20, 2.06
# Transiently divergent feature detected of SNR 1.55, performing quality cut
# 1.72, 2.36, 1.87
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 1.26, 1.44, 1.57
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 0.65, 1.33, 2.07
# Transiently divergent feature detected of SNR 0.65, performing quality cut
# 1.08, 1.44, 1.70
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 1.07, 1.79, 1.71
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 0.70, 0.86, 1.14
# Transiently divergent feature detected of SNR 0.70, performing quality cut
# 1.08, 1.69, 2.24
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 0.96, 0.99, 1.19
# Transiently divergent feature detected of SNR 0.96, performing quality cut
# 1.29, 1.52, 1.71
# Transiently divergent feature detected of SNR 1.29, performing quality cut
# 1.48, 2.17, 1.87
# Transiently divergent feature detected of SNR 1.48, performing quality cut
# 1.77, 2.28, 2.05
# Transiently divergent feature detected of SNR 1.77, performing quality cut
# 1.39, 1.60, 2.24
# Transiently divergent feature detected of SNR 1.39, performing quality cut
# 1.88, 1.99, 2.33
# Transiently divergent feature detected of SNR 1.88, performing quality cut
# 1.45, 2.21, 2.84
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 0.88, 1.68, 1.77
# Transiently divergent feature detected of SNR 0.88, performing quality cut
# 0.93, 1.59, 1.86
# Transiently divergent feature detected of SNR 0.93, performing quality cut
# 1.36, 1.86, 1.41
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 1.93, 1.97, 1.73
# Transiently divergent feature detected of SNR 1.93, performing quality cut
# 2.33, 2.54, 2.08
# Transiently divergent feature detected of SNR 2.33, performing quality cut
# 2.16, 2.45, 2.10
# Transiently divergent feature detected of SNR 2.16, performing quality cut
# 1.36, 1.58, 2.18
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 0.94, 1.96, 1.71
# Transiently divergent feature detected of SNR 0.94, performing quality cut
# 1.50, 2.25, 1.77
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.85, 1.77, 1.36
# 2.26, 2.36, 1.31
# Transiently divergent feature detected of SNR 2.26, performing quality cut
# 1.59, 1.64, 1.31
# Transiently divergent feature detected of SNR 1.59, performing quality cut
# 2.05, 2.55, 1.98
# Transiently divergent feature detected of SNR 2.05, performing quality cut
# 1.51, 1.53, 1.74
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.34, 1.14, 1.46
# Transiently divergent feature detected of SNR 1.34, performing quality cut
# 1.17, 1.09, 2.07
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.85, 1.79, 1.59
# 1.40, 1.31, 1.71
# Transiently divergent feature detected of SNR 1.40, performing quality cut
# 2.37, 2.14, 2.19
# 2.07, 1.79, 1.66
# 2.16, 2.13, 2.22
# Transiently divergent feature detected of SNR 2.16, performing quality cut
# 1.97, 1.89, 2.30
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 1.21, 1.45, 1.63
# Transiently divergent feature detected of SNR 1.21, performing quality cut
# 1.38, 1.21, 1.28
# 2.10, 2.40, 2.57
# Transiently divergent feature detected of SNR 2.10, performing quality cut
# 1.43, 2.01, 2.01
# Transiently divergent feature detected of SNR 1.43, performing quality cut
# 1.03, 1.48, 1.36
# Transiently divergent feature detected of SNR 1.03, performing quality cut
# 0.72, 0.94, 1.68
# Transiently divergent feature detected of SNR 0.72, performing quality cut
# 1.89, 2.51, 1.80
# Transiently divergent feature detected of SNR 1.89, performing quality cut
# 1.58, 1.37, 2.16
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 2.46, 2.51, 1.63
# Transiently divergent feature detected of SNR 2.46, performing quality cut
# 1.11, 1.37, 2.37
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.14, 1.88, 2.41
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 1.14, 1.35, 1.32
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 1.25, 1.46, 1.97
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.99, 2.41, 2.64
# Transiently divergent feature detected of SNR 1.99, performing quality cut
# 0.84, 1.29, 1.95
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 0.74, 1.11, 1.34
# Transiently divergent feature detected of SNR 0.74, performing quality cut
# 1.32, 1.93, 1.54
# Transiently divergent feature detected of SNR 1.32, performing quality cut
# 0.88, 1.67, 2.34
# Transiently divergent feature detected of SNR 0.88, performing quality cut
# 1.06, 1.80, 2.71
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 1.06, 1.87, 1.54
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 1.08, 2.05, 1.83
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 1.10, 0.95, 1.53
# Transiently divergent feature detected of SNR 1.10, performing quality cut
# 1.60, 1.67, 2.13
# Transiently divergent feature detected of SNR 1.60, performing quality cut
# 0.80, 1.00, 1.50
# Transiently divergent feature detected of SNR 0.80, performing quality cut
# 1.45, 1.77, 2.10
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 1.28, 1.92, 2.08
# Transiently divergent feature detected of SNR 1.28, performing quality cut
# 0.67, 1.55, 2.05
# Transiently divergent feature detected of SNR 0.67, performing quality cut
# 1.61, 2.64, 2.80
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 1.09, 1.79, 1.98
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 0.92, 1.37, 1.49
# Transiently divergent feature detected of SNR 0.92, performing quality cut
# 0.88, 1.51, 2.05
# Transiently divergent feature detected of SNR 0.88, performing quality cut
# 1.75, 2.01, 3.05
# Transiently divergent feature detected of SNR 1.75, performing quality cut
# 1.80, 1.57, 1.49
# 1.58, 1.68, 1.80
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.66, 1.54, 1.74
# Transiently divergent feature detected of SNR 1.66, performing quality cut
# 1.68, 1.36, 1.47
# 1.97, 1.86, 2.25
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 1.12, 1.34, 2.64
# Transiently divergent feature detected of SNR 1.12, performing quality cut
# 2.11, 2.35, 2.42
# Transiently divergent feature detected of SNR 2.11, performing quality cut
# 1.56, 1.70, 1.15
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.07, 1.41, 1.44
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 0.94, 1.43, 1.46
# Transiently divergent feature detected of SNR 0.94, performing quality cut
# 2.16, 2.07, 1.80
# 2.26, 1.74, 1.74
# 1.95, 1.83, 1.85
# 1.63, 1.19, 2.50
# Transiently divergent feature detected of SNR 1.63, performing quality cut
# 2.93, 2.66, 2.08
# 2.13, 2.26, 1.66
# Transiently divergent feature detected of SNR 2.13, performing quality cut
# 0.66, 0.99, 1.17
# Transiently divergent feature detected of SNR 0.66, performing quality cut
# 1.08, 1.26, 1.08
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 1.58, 1.76, 2.22
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.41, 1.51, 1.48
# Transiently divergent feature detected of SNR 1.41, performing quality cut
# 2.10, 2.26, 2.22
# Transiently divergent feature detected of SNR 2.10, performing quality cut
# 1.37, 1.84, 1.73
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 0.92, 1.30, 1.53
# Transiently divergent feature detected of SNR 0.92, performing quality cut
# 1.14, 1.77, 1.72
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 0.91, 1.42, 2.93
# Transiently divergent feature detected of SNR 0.91, performing quality cut
# 0.96, 1.58, 2.14
# Transiently divergent feature detected of SNR 0.96, performing quality cut
# 1.52, 1.74, 2.05
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 1.73, 1.83, 1.16
# Transiently divergent feature detected of SNR 1.73, performing quality cut
# 1.15, 1.46, 1.51
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.36, 1.81, 1.94
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 1.16, 1.62, 1.81
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 2.36, 3.01, 3.01
# Transiently divergent feature detected of SNR 2.36, performing quality cut
# 2.06, 1.68, 2.13
# Transiently divergent feature detected of SNR 2.06, performing quality cut
# 1.88, 1.58, 2.00
# Transiently divergent feature detected of SNR 1.88, performing quality cut
# 1.49, 1.29, 1.31
# 1.91, 2.28, 1.77
# Transiently divergent feature detected of SNR 1.91, performing quality cut
# 1.08, 2.01, 2.88
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 0.80, 1.36, 1.72
# Transiently divergent feature detected of SNR 0.80, performing quality cut
# 0.86, 1.19, 1.67
# Transiently divergent feature detected of SNR 0.86, performing quality cut
# 1.52, 1.79, 2.44
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 2.09, 2.26, 2.39
# Transiently divergent feature detected of SNR 2.09, performing quality cut
# 1.63, 2.36, 2.33
# Transiently divergent feature detected of SNR 1.63, performing quality cut
# 1.33, 2.00, 2.05
# Transiently divergent feature detected of SNR 1.33, performing quality cut
# 0.94, 1.32, 1.72
# Transiently divergent feature detected of SNR 0.94, performing quality cut
# 1.52, 2.48, 3.12
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 1.89, 2.14, 2.26
# Transiently divergent feature detected of SNR 1.89, performing quality cut
# 1.52, 1.87, 2.37
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 1.70, 2.74, 3.26
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.42, 1.78, 1.36
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 1.29, 1.62, 1.63
# Transiently divergent feature detected of SNR 1.29, performing quality cut
# 1.25, 2.04, 1.90
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.19, 1.54, 1.67
# Transiently divergent feature detected of SNR 1.19, performing quality cut
# 1.54, 2.53, 1.96
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 1.50, 2.03, 2.25
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.16, 1.95, 2.60
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 0.90, 1.58, 1.91
# Transiently divergent feature detected of SNR 0.90, performing quality cut
# 1.54, 2.38, 2.08
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 1.47, 1.79, 2.48
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 1.50, 2.22, 2.69
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.72, 1.56, 1.55
# 2.10, 2.84, 2.46
# Transiently divergent feature detected of SNR 2.10, performing quality cut
# 1.22, 2.31, 3.50
# Transiently divergent feature detected of SNR 1.22, performing quality cut
# 0.61, 1.10, 1.26
# Transiently divergent feature detected of SNR 0.61, performing quality cut
# 0.97, 1.18, 0.97
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 0.62, 0.83, 1.09
# Transiently divergent feature detected of SNR 0.62, performing quality cut
# 1.45, 1.98, 1.50
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 1.46, 1.99, 2.20
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.39, 1.54, 1.23
# Transiently divergent feature detected of SNR 1.39, performing quality cut
# 1.21, 2.10, 2.50
# Transiently divergent feature detected of SNR 1.21, performing quality cut
# 0.90, 1.26, 1.50
# Transiently divergent feature detected of SNR 0.90, performing quality cut
# 0.75, 1.03, 1.42
# Transiently divergent feature detected of SNR 0.75, performing quality cut
# 1.11, 1.81, 1.75
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.97, 2.01, 1.63
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 1.64, 1.94, 1.46
# Transiently divergent feature detected of SNR 1.64, performing quality cut
# 0.94, 1.40, 1.84
# Transiently divergent feature detected of SNR 0.94, performing quality cut
# 1.13, 1.62, 1.96
# Transiently divergent feature detected of SNR 1.13, performing quality cut
# 1.11, 1.68, 2.14
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.16, 1.66, 1.54
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 0.82, 1.16, 1.34
# Transiently divergent feature detected of SNR 0.82, performing quality cut
# 1.11, 1.28, 1.34
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 2.00, 2.85, 2.04
# Transiently divergent feature detected of SNR 2.00, performing quality cut
# 1.39, 1.63, 1.65
# Transiently divergent feature detected of SNR 1.39, performing quality cut
# 1.23, 1.41, 1.49
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 1.23, 1.52, 1.99
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 1.72, 1.99, 1.78
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 1.23, 1.74, 2.17
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 1.87, 1.80, 1.84
# 2.18, 2.07, 1.65
# 1.25, 0.80, 1.12
# 2.18, 2.25, 1.96
# Transiently divergent feature detected of SNR 2.18, performing quality cut
# 1.99, 1.89, 2.22
# Transiently divergent feature detected of SNR 1.99, performing quality cut
# 1.56, 1.89, 1.95
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.57, 1.61, 1.24
# Transiently divergent feature detected of SNR 1.57, performing quality cut
# 2.02, 2.18, 1.57
# Transiently divergent feature detected of SNR 2.02, performing quality cut
# 1.87, 1.73, 1.93
# Transiently divergent feature detected of SNR 1.87, performing quality cut
# 1.74, 1.90, 1.67
# Transiently divergent feature detected of SNR 1.74, performing quality cut
# 2.03, 2.10, 1.52
# Transiently divergent feature detected of SNR 2.03, performing quality cut
# 1.26, 1.41, 1.55
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 1.65, 2.26, 2.65
# Transiently divergent feature detected of SNR 1.65, performing quality cut
# 0.82, 1.18, 1.96
# Transiently divergent feature detected of SNR 0.82, performing quality cut
# 1.11, 1.60, 1.87
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.45, 1.74, 1.63
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 2.21, 1.93, 2.18
# 1.70, 1.28, 1.61
# 1.61, 1.58, 1.95
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 1.73, 2.13, 2.55
# Transiently divergent feature detected of SNR 1.73, performing quality cut
# 1.85, 1.73, 1.41
# 1.61, 2.08, 2.34
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 1.70, 2.01, 1.56
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.66, 2.03, 1.90
# Transiently divergent feature detected of SNR 1.66, performing quality cut
# 1.48, 1.54, 2.01
# Transiently divergent feature detected of SNR 1.48, performing quality cut
# 1.47, 1.43, 1.92
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 1.93, 1.99, 2.03
# Transiently divergent feature detected of SNR 1.93, performing quality cut
# 1.79, 3.52, 3.60
# Transiently divergent feature detected of SNR 1.79, performing quality cut
# 0.97, 1.29, 1.97
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 1.71, 2.45, 3.23
# Transiently divergent feature detected of SNR 1.71, performing quality cut
# 1.04, 1.49, 1.68
# Transiently divergent feature detected of SNR 1.04, performing quality cut
# 1.46, 1.61, 2.24
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.59, 1.88, 1.44
# Transiently divergent feature detected of SNR 1.59, performing quality cut
# 1.57, 2.14, 2.69
# Transiently divergent feature detected of SNR 1.57, performing quality cut
# 1.72, 1.84, 1.85
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 2.29, 2.18, 2.57
# Transiently divergent feature detected of SNR 2.29, performing quality cut
# 2.02, 2.57, 3.20
# Transiently divergent feature detected of SNR 2.02, performing quality cut
# 2.22, 2.14, 2.10
# 2.99, 2.21, 1.29
# 2.54, 2.29, 1.40
# 1.96, 1.95, 1.55
# 1.15, 2.08, 2.22
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 2.24, 2.76, 2.81
# Transiently divergent feature detected of SNR 2.24, performing quality cut
# 0.78, 1.00, 1.86
# Transiently divergent feature detected of SNR 0.78, performing quality cut
# 0.56, 0.77, 1.35
# Transiently divergent feature detected of SNR 0.56, performing quality cut
# 1.34, 1.45, 1.58
# Transiently divergent feature detected of SNR 1.34, performing quality cut
# 2.80, 3.06, 1.98
# Transiently divergent feature detected of SNR 2.80, performing quality cut
# 2.30, 1.83, 1.67
# 2.04, 1.82, 2.44
# Transiently divergent feature detected of SNR 2.04, performing quality cut
# 1.94, 1.58, 1.37
# 1.38, 1.34, 1.53
# Transiently divergent feature detected of SNR 1.38, performing quality cut
# 1.69, 1.99, 2.73
# Transiently divergent feature detected of SNR 1.69, performing quality cut
# 1.68, 2.17, 2.63
# Transiently divergent feature detected of SNR 1.68, performing quality cut
# 1.59, 1.87, 1.26
# Transiently divergent feature detected of SNR 1.59, performing quality cut
# 1.24, 1.74, 1.66
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.26, 1.30, 1.77
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 2.37, 2.45, 2.15
# Transiently divergent feature detected of SNR 2.37, performing quality cut
# 1.70, 1.33, 1.64
# 1.82, 1.82, 1.65
# 1.84, 2.58, 2.49
# Transiently divergent feature detected of SNR 1.84, performing quality cut
# 1.27, 2.14, 2.21
# Transiently divergent feature detected of SNR 1.27, performing quality cut
# 0.74, 1.35, 1.75
# Transiently divergent feature detected of SNR 0.74, performing quality cut
# 1.20, 1.53, 1.88
# Transiently divergent feature detected of SNR 1.20, performing quality cut
# 1.32, 1.49, 2.28
# Transiently divergent feature detected of SNR 1.32, performing quality cut
# 1.17, 1.09, 1.18
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.47, 1.73, 1.68
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 2.07, 1.82, 1.66
# 1.13, 1.59, 2.39
# Transiently divergent feature detected of SNR 1.13, performing quality cut
# 1.38, 2.19, 2.53
# Transiently divergent feature detected of SNR 1.38, performing quality cut
# 1.11, 1.27, 1.68
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.67, 1.72, 2.73
# Transiently divergent feature detected of SNR 1.67, performing quality cut
# 2.12, 2.23, 2.11
# Transiently divergent feature detected of SNR 2.12, performing quality cut
# 1.94, 2.86, 2.08
# Transiently divergent feature detected of SNR 1.94, performing quality cut
# 0.99, 1.52, 1.46
# Transiently divergent feature detected of SNR 0.99, performing quality cut
# 1.42, 1.39, 1.84
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 1.55, 2.00, 2.20
# Transiently divergent feature detected of SNR 1.55, performing quality cut
# 1.60, 1.82, 1.73
# Transiently divergent feature detected of SNR 1.60, performing quality cut
# 1.05, 1.45, 2.29
# Transiently divergent feature detected of SNR 1.05, performing quality cut
# 1.14, 1.65, 2.17
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 1.68, 2.29, 1.60
# Transiently divergent feature detected of SNR 1.68, performing quality cut
# 0.78, 1.85, 1.83
# Transiently divergent feature detected of SNR 0.78, performing quality cut
# 1.05, 1.55, 1.91
# Transiently divergent feature detected of SNR 1.05, performing quality cut
# 1.16, 1.26, 1.63
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 2.66, 2.81, 2.50
# Transiently divergent feature detected of SNR 2.66, performing quality cut
# 2.10, 2.17, 1.98
# Transiently divergent feature detected of SNR 2.10, performing quality cut
# 2.16, 2.34, 1.58
# Transiently divergent feature detected of SNR 2.16, performing quality cut
# 1.24, 1.60, 2.10
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.55, 1.85, 1.88
# Transiently divergent feature detected of SNR 1.55, performing quality cut
# 1.02, 1.63, 1.99
# Transiently divergent feature detected of SNR 1.02, performing quality cut
# 1.09, 1.98, 2.02
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 0.93, 1.85, 2.10
# Transiently divergent feature detected of SNR 0.93, performing quality cut
# 0.80, 1.46, 1.69
# Transiently divergent feature detected of SNR 0.80, performing quality cut
# 0.89, 1.41, 2.26
# Transiently divergent feature detected of SNR 0.89, performing quality cut
# 1.46, 1.61, 1.65
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 2.01, 1.99, 1.42
# 1.81, 2.15, 2.05
# Transiently divergent feature detected of SNR 1.81, performing quality cut
# 1.92, 2.47, 2.12
# Transiently divergent feature detected of SNR 1.92, performing quality cut
# 0.75, 1.31, 2.23
# Transiently divergent feature detected of SNR 0.75, performing quality cut
# 1.42, 1.64, 1.91
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 1.50, 1.87, 1.81
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.78, 1.83, 1.78
# Transiently divergent feature detected of SNR 1.78, performing quality cut
# 2.27, 2.65, 2.54
# Transiently divergent feature detected of SNR 2.27, performing quality cut
# 2.64, 3.74, 2.86
# Transiently divergent feature detected of SNR 2.64, performing quality cut
# 1.65, 1.66, 1.84
# Transiently divergent feature detected of SNR 1.65, performing quality cut
# 1.52, 1.50, 1.63
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 2.10, 2.14, 1.99
# Transiently divergent feature detected of SNR 2.10, performing quality cut
# 1.53, 1.31, 1.62
# Transiently divergent feature detected of SNR 1.53, performing quality cut
# 1.06, 1.45, 1.36
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 1.99, 1.87, 1.62
# 1.72, 1.90, 1.86
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 2.42, 2.83, 2.32
# Transiently divergent feature detected of SNR 2.42, performing quality cut
# 0.87, 1.20, 2.00
# Transiently divergent feature detected of SNR 0.87, performing quality cut
# 0.87, 1.44, 1.73
# Transiently divergent feature detected of SNR 0.87, performing quality cut
# 0.79, 1.37, 1.75
# Transiently divergent feature detected of SNR 0.79, performing quality cut
# 1.61, 1.76, 1.77
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 1.31, 1.28, 1.54
# Transiently divergent feature detected of SNR 1.31, performing quality cut
# 2.04, 1.95, 1.59
# 1.14, 1.19, 1.80
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 2.33, 2.27, 1.63
# 2.88, 2.77, 2.19
# 1.36, 1.31, 1.81
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 1.78, 1.86, 1.22
# Transiently divergent feature detected of SNR 1.78, performing quality cut
# 2.40, 2.35, 1.82
# 1.87, 1.75, 2.52
# Transiently divergent feature detected of SNR 1.87, performing quality cut
# 2.09, 1.61, 1.26
# 2.69, 2.82, 2.91
# Transiently divergent feature detected of SNR 2.69, performing quality cut
# 1.81, 2.07, 2.45
# Transiently divergent feature detected of SNR 1.81, performing quality cut
# 1.30, 1.64, 1.75
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 1.70, 2.40, 2.15
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.20, 1.90, 1.71
# Transiently divergent feature detected of SNR 1.20, performing quality cut
# 0.85, 1.00, 1.10
# Transiently divergent feature detected of SNR 0.85, performing quality cut
# 1.34, 1.31, 1.96
# Transiently divergent feature detected of SNR 1.34, performing quality cut
# 1.80, 2.10, 1.84
# Transiently divergent feature detected of SNR 1.80, performing quality cut
# 1.47, 1.75, 1.80
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 1.43, 2.12, 1.82
# Transiently divergent feature detected of SNR 1.43, performing quality cut
# 0.78, 1.17, 1.42
# Transiently divergent feature detected of SNR 0.78, performing quality cut
# 0.57, 0.64, 0.94
# Transiently divergent feature detected of SNR 0.57, performing quality cut
# 0.68, 0.93, 0.99
# Transiently divergent feature detected of SNR 0.68, performing quality cut
# 1.36, 1.48, 1.53
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 1.42, 2.61, 2.95
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 1.38, 2.08, 1.64
# Transiently divergent feature detected of SNR 1.38, performing quality cut
# 1.36, 1.96, 2.14
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 1.15, 1.47, 1.70
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 0.97, 1.32, 2.08
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 1.50, 1.95, 1.67
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.54, 1.65, 1.45
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 1.17, 1.63, 1.61
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.77, 1.69, 1.35
# 1.23, 1.60, 1.56
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 1.63, 2.30, 2.14
# Transiently divergent feature detected of SNR 1.63, performing quality cut
# 1.34, 2.21, 2.49
# Transiently divergent feature detected of SNR 1.34, performing quality cut
# 1.16, 1.97, 2.59
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 1.37, 2.22, 3.02
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 0.97, 1.85, 2.51
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 0.70, 1.10, 1.44
# Transiently divergent feature detected of SNR 0.70, performing quality cut
# 0.83, 1.17, 1.50
# Transiently divergent feature detected of SNR 0.83, performing quality cut
# 1.25, 2.08, 2.71
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.15, 1.18, 1.52
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.68, 1.86, 1.65
# Transiently divergent feature detected of SNR 1.68, performing quality cut
# 1.07, 1.51, 2.37
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 0.84, 0.98, 1.58
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 2.04, 2.20, 2.16
# Transiently divergent feature detected of SNR 2.04, performing quality cut
# 1.91, 1.42, 1.21
# 1.82, 1.46, 1.03
# 2.97, 2.68, 2.02
# 2.44, 2.72, 2.61
# Transiently divergent feature detected of SNR 2.44, performing quality cut
# 2.18, 2.38, 2.34
# Transiently divergent feature detected of SNR 2.18, performing quality cut
# 1.77, 1.81, 2.11
# Transiently divergent feature detected of SNR 1.77, performing quality cut
# 1.46, 1.79, 1.29
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.40, 1.40, 1.22
# 1.61, 1.33, 1.54
# 2.34, 2.18, 1.33
# 2.30, 1.95, 2.01
# 2.12, 2.10, 1.75
# 2.18, 2.09, 2.50
# Transiently divergent feature detected of SNR 2.18, performing quality cut
# 1.07, 1.08, 1.84
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 1.76, 1.98, 2.83
# Transiently divergent feature detected of SNR 1.76, performing quality cut
# 1.35, 1.76, 2.63
# Transiently divergent feature detected of SNR 1.35, performing quality cut
# 1.50, 1.58, 1.57
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 2.35, 2.10, 1.39
# 1.14, 1.73, 1.98
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 1.73, 1.80, 2.17
# Transiently divergent feature detected of SNR 1.73, performing quality cut
# 1.22, 1.09, 1.26
# Transiently divergent feature detected of SNR 1.22, performing quality cut
# 1.70, 2.01, 2.01
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.76, 2.13, 2.19
# Transiently divergent feature detected of SNR 1.76, performing quality cut
# 1.11, 1.18, 1.73
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.44, 1.75, 1.78
# Transiently divergent feature detected of SNR 1.44, performing quality cut
# 1.20, 1.42, 1.25
# Transiently divergent feature detected of SNR 1.20, performing quality cut
# 1.54, 1.44, 1.17
# 1.97, 2.24, 2.26
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 1.95, 2.06, 2.22
# Transiently divergent feature detected of SNR 1.95, performing quality cut
# 2.38, 2.15, 1.95
# 2.49, 2.63, 1.56
# Transiently divergent feature detected of SNR 2.49, performing quality cut
# 1.53, 1.94, 1.89
# Transiently divergent feature detected of SNR 1.53, performing quality cut
# 1.17, 1.67, 2.09
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 0.93, 1.25, 2.21
# Transiently divergent feature detected of SNR 0.93, performing quality cut
# 1.15, 2.02, 1.82
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.02, 1.83, 2.79
# Transiently divergent feature detected of SNR 1.02, performing quality cut
# 0.38, 1.01, 1.86
# Transiently divergent feature detected of SNR 0.38, performing quality cut
# 1.09, 1.64, 1.76
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 1.21, 1.94, 2.06
# Transiently divergent feature detected of SNR 1.21, performing quality cut
# 1.19, 2.02, 1.96
# Transiently divergent feature detected of SNR 1.19, performing quality cut
# 1.58, 1.88, 2.10
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.28, 1.36, 1.49
# Transiently divergent feature detected of SNR 1.28, performing quality cut
# 1.39, 1.21, 1.47
# Transiently divergent feature detected of SNR 1.39, performing quality cut
# 1.47, 1.73, 1.68
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 0.90, 1.75, 1.43
# Transiently divergent feature detected of SNR 0.90, performing quality cut
# 1.52, 1.64, 1.90
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 1.63, 1.08, 1.51
# 2.67, 2.40, 1.36
# 2.13, 2.34, 2.42
# Transiently divergent feature detected of SNR 2.13, performing quality cut
# 1.60, 1.38, 1.82
# Transiently divergent feature detected of SNR 1.60, performing quality cut
# 1.56, 1.87, 1.99
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 2.27, 2.10, 3.04
# Transiently divergent feature detected of SNR 2.27, performing quality cut
# 2.02, 1.88, 2.18
# Transiently divergent feature detected of SNR 2.02, performing quality cut
# 1.72, 1.35, 1.50
# 1.93, 1.62, 1.21
# 1.83, 1.96, 2.08
# Transiently divergent feature detected of SNR 1.83, performing quality cut
# 2.01, 2.26, 1.85
# Transiently divergent feature detected of SNR 2.01, performing quality cut
# 1.30, 1.33, 1.94
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 0.92, 1.52, 1.53
# Transiently divergent feature detected of SNR 0.92, performing quality cut
# 1.45, 1.84, 2.28
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 1.24, 1.40, 2.12
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 2.32, 3.22, 2.25
# Transiently divergent feature detected of SNR 2.32, performing quality cut
# 0.91, 1.60, 1.18
# Transiently divergent feature detected of SNR 0.91, performing quality cut
# 1.51, 1.80, 2.20
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.70, 1.83, 1.38
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.56, 1.53, 1.73
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.82, 1.98, 2.08
# Transiently divergent feature detected of SNR 1.82, performing quality cut
# 1.49, 2.40, 2.01
# Transiently divergent feature detected of SNR 1.49, performing quality cut
# 0.65, 1.00, 1.61
# Transiently divergent feature detected of SNR 0.65, performing quality cut
# 2.13, 2.59, 2.45
# Transiently divergent feature detected of SNR 2.13, performing quality cut
# 1.54, 1.59, 1.46
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 1.75, 1.78, 1.44
# Transiently divergent feature detected of SNR 1.75, performing quality cut
# 1.72, 1.52, 1.27
# 1.97, 1.72, 2.20
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 1.61, 1.59, 1.64
# Transiently divergent feature detected of SNR 1.61, performing quality cut
# 0.94, 1.57, 1.51
# Transiently divergent feature detected of SNR 0.94, performing quality cut
# 0.55, 0.90, 1.95
# Transiently divergent feature detected of SNR 0.55, performing quality cut
# 1.21, 1.51, 1.32
# Transiently divergent feature detected of SNR 1.21, performing quality cut
# 1.15, 1.13, 1.23
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.51, 2.11, 3.02
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.41, 1.47, 1.79
# Transiently divergent feature detected of SNR 1.41, performing quality cut
# 1.10, 1.32, 1.27
# Transiently divergent feature detected of SNR 1.10, performing quality cut
# 1.72, 2.07, 1.81
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 1.30, 1.47, 1.58
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 1.11, 1.66, 2.63
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.05, 1.41, 1.90
# Transiently divergent feature detected of SNR 1.05, performing quality cut
# 1.27, 1.65, 1.83
# Transiently divergent feature detected of SNR 1.27, performing quality cut
# 1.11, 1.53, 2.34
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 0.80, 1.04, 1.90
# Transiently divergent feature detected of SNR 0.80, performing quality cut
# 1.49, 1.91, 1.53
# Transiently divergent feature detected of SNR 1.49, performing quality cut
# 1.24, 1.49, 1.67
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.40, 1.58, 1.66
# Transiently divergent feature detected of SNR 1.40, performing quality cut
# 1.84, 2.23, 2.31
# Transiently divergent feature detected of SNR 1.84, performing quality cut
# 1.30, 1.95, 1.89
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 0.72, 1.33, 1.87
# Transiently divergent feature detected of SNR 0.72, performing quality cut
# 1.20, 1.43, 1.48
# Transiently divergent feature detected of SNR 1.20, performing quality cut
# 1.54, 2.04, 1.84
# Transiently divergent feature detected of SNR 1.54, performing quality cut
# 0.99, 1.53, 1.55
# Transiently divergent feature detected of SNR 0.99, performing quality cut
# 0.60, 0.75, 1.37
# Transiently divergent feature detected of SNR 0.60, performing quality cut
# 1.16, 1.86, 1.67
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 1.17, 2.20, 2.30
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.49, 1.82, 2.04
# Transiently divergent feature detected of SNR 1.49, performing quality cut
# 1.43, 1.76, 1.49
# Transiently divergent feature detected of SNR 1.43, performing quality cut
# 0.88, 1.90, 2.46
# Transiently divergent feature detected of SNR 0.88, performing quality cut
# 0.84, 1.72, 2.48
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 0.61, 0.97, 1.40
# Transiently divergent feature detected of SNR 0.61, performing quality cut
# 0.84, 1.04, 2.14
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 2.22, 2.66, 2.42
# Transiently divergent feature detected of SNR 2.22, performing quality cut
# 1.61, 1.58, 1.51
# 1.77, 1.78, 1.40
# Transiently divergent feature detected of SNR 1.77, performing quality cut
# 1.81, 2.22, 2.26
# Transiently divergent feature detected of SNR 1.81, performing quality cut
# 1.48, 1.66, 1.70
# Transiently divergent feature detected of SNR 1.48, performing quality cut
# 1.16, 2.06, 1.62
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 1.17, 1.19, 1.82
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.62, 1.45, 1.25
# 1.99, 2.24, 1.84
# Transiently divergent feature detected of SNR 1.99, performing quality cut
# 1.28, 2.11, 3.22
# Transiently divergent feature detected of SNR 1.28, performing quality cut
# 1.36, 2.07, 1.59
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 0.48, 0.74, 1.11
# Transiently divergent feature detected of SNR 0.48, performing quality cut
# 1.31, 1.67, 1.59
# Transiently divergent feature detected of SNR 1.31, performing quality cut
# 1.68, 2.09, 2.11
# Transiently divergent feature detected of SNR 1.68, performing quality cut
# 1.72, 2.12, 2.65
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 1.74, 1.94, 1.87
# Transiently divergent feature detected of SNR 1.74, performing quality cut
# 1.35, 1.21, 1.33
# 1.70, 1.29, 0.92
# 1.95, 2.03, 1.89
# Transiently divergent feature detected of SNR 1.95, performing quality cut
# 2.64, 2.53, 3.78
# Transiently divergent feature detected of SNR 2.64, performing quality cut
# 1.59, 1.69, 1.61
# Transiently divergent feature detected of SNR 1.59, performing quality cut
# 1.27, 2.02, 1.81
# Transiently divergent feature detected of SNR 1.27, performing quality cut
# 1.33, 1.67, 1.74
# Transiently divergent feature detected of SNR 1.33, performing quality cut
# 1.23, 1.65, 1.24
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 0.89, 1.61, 1.77
# Transiently divergent feature detected of SNR 0.89, performing quality cut
# 1.46, 1.71, 1.63
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.09, 1.75, 1.68
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 1.48, 2.30, 1.87
# Transiently divergent feature detected of SNR 1.48, performing quality cut
# 0.83, 1.09, 1.67
# Transiently divergent feature detected of SNR 0.83, performing quality cut
# 1.73, 2.43, 2.71
# Transiently divergent feature detected of SNR 1.73, performing quality cut
# 1.24, 1.40, 2.27
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 0.96, 1.16, 1.51
# Transiently divergent feature detected of SNR 0.96, performing quality cut
# 1.19, 1.55, 2.09
# Transiently divergent feature detected of SNR 1.19, performing quality cut
# 0.88, 1.42, 1.60
# Transiently divergent feature detected of SNR 0.88, performing quality cut
# 1.23, 1.91, 2.17
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 0.83, 1.52, 1.50
# Transiently divergent feature detected of SNR 0.83, performing quality cut
# 0.57, 0.89, 1.08
# Transiently divergent feature detected of SNR 0.57, performing quality cut
# 0.84, 0.84, 1.02
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 1.53, 1.75, 2.31
# Transiently divergent feature detected of SNR 1.53, performing quality cut
# 1.56, 1.64, 2.02
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.33, 1.78, 1.52
# Transiently divergent feature detected of SNR 1.33, performing quality cut
# 1.35, 2.03, 1.95
# Transiently divergent feature detected of SNR 1.35, performing quality cut
# 1.44, 2.47, 2.28
# Transiently divergent feature detected of SNR 1.44, performing quality cut
# 0.68, 1.30, 2.14
# Transiently divergent feature detected of SNR 0.68, performing quality cut
# 1.37, 1.61, 1.65
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 1.07, 1.25, 1.43
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 1.71, 2.21, 2.06
# Transiently divergent feature detected of SNR 1.71, performing quality cut
# 1.06, 1.23, 1.44
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 1.10, 1.34, 1.59
# Transiently divergent feature detected of SNR 1.10, performing quality cut
# 1.40, 1.60, 2.34
# Transiently divergent feature detected of SNR 1.40, performing quality cut
# 1.83, 2.11, 1.93
# Transiently divergent feature detected of SNR 1.83, performing quality cut
# 1.60, 1.65, 1.94
# Transiently divergent feature detected of SNR 1.60, performing quality cut
# 1.82, 1.34, 1.60
# 1.88, 2.34, 2.03
# Transiently divergent feature detected of SNR 1.88, performing quality cut
# 1.70, 2.42, 2.27
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.55, 1.88, 2.33
# Transiently divergent feature detected of SNR 1.55, performing quality cut
# 1.78, 1.48, 1.55
# 1.26, 2.37, 2.14
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 1.27, 1.61, 1.22
# Transiently divergent feature detected of SNR 1.27, performing quality cut
# 1.40, 1.84, 1.79
# Transiently divergent feature detected of SNR 1.40, performing quality cut
# 1.11, 1.75, 2.09
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 0.93, 1.82, 2.24
# Transiently divergent feature detected of SNR 0.93, performing quality cut
# 1.16, 2.04, 2.50
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 1.13, 1.71, 1.72
# Transiently divergent feature detected of SNR 1.13, performing quality cut
# 0.76, 1.23, 1.99
# Transiently divergent feature detected of SNR 0.76, performing quality cut
# 1.25, 1.52, 1.13
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.16, 1.69, 1.78
# Transiently divergent feature detected of SNR 1.16, performing quality cut
# 1.06, 1.43, 1.66
# Transiently divergent feature detected of SNR 1.06, performing quality cut
# 0.97, 1.17, 1.94
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 1.41, 1.74, 1.83
# Transiently divergent feature detected of SNR 1.41, performing quality cut
# 1.20, 1.61, 1.33
# Transiently divergent feature detected of SNR 1.20, performing quality cut
# 0.82, 1.65, 1.97
# Transiently divergent feature detected of SNR 0.82, performing quality cut
# 1.26, 1.56, 1.54
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 0.75, 1.21, 1.59
# Transiently divergent feature detected of SNR 0.75, performing quality cut
# 1.13, 2.32, 1.85
# Transiently divergent feature detected of SNR 1.13, performing quality cut
# 0.68, 1.39, 1.84
# Transiently divergent feature detected of SNR 0.68, performing quality cut
# 1.18, 1.33, 1.53
# Transiently divergent feature detected of SNR 1.18, performing quality cut
# 1.35, 1.77, 1.89
# Transiently divergent feature detected of SNR 1.35, performing quality cut
# 0.85, 1.09, 1.40
# Transiently divergent feature detected of SNR 0.85, performing quality cut
# 1.49, 1.74, 1.94
# Transiently divergent feature detected of SNR 1.49, performing quality cut
# 1.07, 1.51, 1.77
# Transiently divergent feature detected of SNR 1.07, performing quality cut
# 1.66, 1.54, 1.54
# 2.51, 3.08, 2.42
# Transiently divergent feature detected of SNR 2.51, performing quality cut
# 1.48, 1.97, 2.24
# Transiently divergent feature detected of SNR 1.48, performing quality cut
# 1.17, 1.75, 2.60
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 0.86, 1.17, 1.37
# Transiently divergent feature detected of SNR 0.86, performing quality cut
# 1.18, 1.40, 1.70
# Transiently divergent feature detected of SNR 1.18, performing quality cut
# 1.58, 1.72, 2.00
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.24, 1.83, 1.34
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 0.97, 1.62, 2.07
# Transiently divergent feature detected of SNR 0.97, performing quality cut
# 0.96, 1.43, 1.94
# Transiently divergent feature detected of SNR 0.96, performing quality cut
# 1.15, 1.81, 2.02
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.80, 2.46, 1.97
# Transiently divergent feature detected of SNR 1.80, performing quality cut
# 1.73, 1.56, 1.20
# 1.31, 1.32, 1.22
# Transiently divergent feature detected of SNR 1.31, performing quality cut
# 1.65, 2.19, 2.00
# Transiently divergent feature detected of SNR 1.65, performing quality cut
# 0.90, 1.14, 1.97
# Transiently divergent feature detected of SNR 0.90, performing quality cut
# 1.47, 2.29, 2.94
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 0.55, 1.40, 1.66
# Transiently divergent feature detected of SNR 0.55, performing quality cut
# 1.33, 1.79, 3.13
# Transiently divergent feature detected of SNR 1.33, performing quality cut
# 1.77, 1.79, 1.83
# Transiently divergent feature detected of SNR 1.77, performing quality cut
# 1.37, 1.32, 1.36
# 2.05, 2.04, 2.73
# Transiently divergent feature detected of SNR 2.05, performing quality cut
# 1.18, 1.47, 1.99
# Transiently divergent feature detected of SNR 1.18, performing quality cut
# 1.11, 1.45, 1.65
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.90, 2.57, 2.04
# Transiently divergent feature detected of SNR 1.90, performing quality cut
# 1.51, 2.21, 1.98
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.01, 1.24, 1.61
# Transiently divergent feature detected of SNR 1.01, performing quality cut
# 1.50, 2.34, 2.73
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 1.40, 1.89, 1.42
# Transiently divergent feature detected of SNR 1.40, performing quality cut
# 1.24, 1.98, 1.61
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 0.81, 1.97, 2.85
# Transiently divergent feature detected of SNR 0.81, performing quality cut
# 0.99, 1.40, 1.77
# Transiently divergent feature detected of SNR 0.99, performing quality cut
# 1.30, 1.40, 1.50
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 1.70, 2.38, 2.27
# Transiently divergent feature detected of SNR 1.70, performing quality cut
# 1.96, 2.37, 1.50
# Transiently divergent feature detected of SNR 1.96, performing quality cut
# 1.84, 2.20, 1.58
# Transiently divergent feature detected of SNR 1.84, performing quality cut
# 1.45, 1.67, 1.79
# Transiently divergent feature detected of SNR 1.45, performing quality cut
# 1.63, 2.03, 1.71
# Transiently divergent feature detected of SNR 1.63, performing quality cut
# 2.15, 3.05, 2.63
# Transiently divergent feature detected of SNR 2.15, performing quality cut
# 1.23, 2.21, 3.03
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 0.85, 1.55, 1.68
# Transiently divergent feature detected of SNR 0.85, performing quality cut
# 1.02, 2.07, 1.99
# Transiently divergent feature detected of SNR 1.02, performing quality cut
# 1.09, 1.58, 1.80
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 1.28, 1.34, 2.00
# ...
# Transiently divergent feature detected of SNR 1.21, performing quality cut
# 1.99, 2.04, 1.71
# Transiently divergent feature detected of SNR 1.99, performing quality cut
# 2.07, 2.11, 1.63
# Transiently divergent feature detected of SNR 2.07, performing quality cut
# 1.37, 1.41, 1.98
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 1.49, 1.88, 1.73
# Transiently divergent feature detected of SNR 1.49, performing quality cut
# 1.44, 1.39, 1.52
# Transiently divergent feature detected of SNR 1.44, performing quality cut
# 1.24, 1.38, 1.49
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.50, 1.70, 1.66
# Transiently divergent feature detected of SNR 1.50, performing quality cut
# 2.05, 1.65, 1.40
# 2.35, 1.81, 1.41
# 1.53, 1.69, 1.68
# Transiently divergent feature detected of SNR 1.53, performing quality cut
# 1.95, 2.70, 2.77
# Transiently divergent feature detected of SNR 1.95, performing quality cut
# 1.11, 1.40, 1.45
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 1.51, 2.15, 2.13
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 2.00, 2.03, 1.46
# Transiently divergent feature detected of SNR 2.00, performing quality cut
# 1.39, 2.40, 2.34
# Transiently divergent feature detected of SNR 1.39, performing quality cut
# 1.17, 2.09, 2.76
# Transiently divergent feature detected of SNR 1.17, performing quality cut
# 1.24, 1.83, 2.10
# Transiently divergent feature detected of SNR 1.24, performing quality cut
# 1.11, 1.33, 1.10
# Transiently divergent feature detected of SNR 1.11, performing quality cut
# 0.84, 1.27, 1.55
# Transiently divergent feature detected of SNR 0.84, performing quality cut
# 1.08, 1.16, 0.70
# Transiently divergent feature detected of SNR 1.08, performing quality cut
# 1.13, 1.32, 1.39
# Transiently divergent feature detected of SNR 1.13, performing quality cut
# 1.47, 1.75, 1.40
# Transiently divergent feature detected of SNR 1.47, performing quality cut
# 1.37, 2.05, 1.99
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 1.42, 1.85, 1.85
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 1.23, 1.31, 0.90
# Transiently divergent feature detected of SNR 1.23, performing quality cut
# 1.80, 1.68, 1.48
# 2.33, 2.34, 1.81
# Transiently divergent feature detected of SNR 2.33, performing quality cut
# 1.64, 1.59, 1.92
# Transiently divergent feature detected of SNR 1.64, performing quality cut
# 1.96, 1.60, 1.49
# 2.53, 2.61, 1.59
# Transiently divergent feature detected of SNR 2.53, performing quality cut
# 1.97, 3.09, 2.76
# Transiently divergent feature detected of SNR 1.97, performing quality cut
# 2.13, 2.49, 1.66
# Transiently divergent feature detected of SNR 2.13, performing quality cut
# 1.15, 1.60, 1.27
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.87, 2.25, 1.70
# Transiently divergent feature detected of SNR 1.87, performing quality cut
# 1.58, 1.59, 1.50
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.80, 1.59, 1.19
# 2.00, 2.19, 2.40
# Transiently divergent feature detected of SNR 2.00, performing quality cut
# 0.99, 0.95, 0.97
# 2.42, 3.45, 4.52
# Transiently divergent feature detected of SNR 2.42, performing quality cut
# 1.37, 1.52, 1.74
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 1.72, 2.39, 1.63
# Transiently divergent feature detected of SNR 1.72, performing quality cut
# 1.52, 1.54, 1.20
# Transiently divergent feature detected of SNR 1.52, performing quality cut
# 2.27, 2.09, 1.52
# 1.91, 2.33, 2.35
# Transiently divergent feature detected of SNR 1.91, performing quality cut
# 1.77, 1.85, 2.17
# Transiently divergent feature detected of SNR 1.77, performing quality cut
# 1.43, 2.18, 2.04
# Transiently divergent feature detected of SNR 1.43, performing quality cut
# 1.56, 2.14, 2.33
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.25, 1.52, 1.43
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.46, 2.03, 1.71
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.32, 2.04, 2.55
# Transiently divergent feature detected of SNR 1.32, performing quality cut
# 1.37, 1.99, 2.61
# Transiently divergent feature detected of SNR 1.37, performing quality cut
# 1.15, 2.01, 1.89
# Transiently divergent feature detected of SNR 1.15, performing quality cut
# 1.88, 2.23, 2.99
# Transiently divergent feature detected of SNR 1.88, performing quality cut
# 1.56, 1.84, 1.90
# Transiently divergent feature detected of SNR 1.56, performing quality cut
# 1.31, 1.04, 1.48
# Transiently divergent feature detected of SNR 1.31, performing quality cut
# 1.99, 2.08, 2.12
# Transiently divergent feature detected of SNR 1.99, performing quality cut
# 2.18, 2.17, 3.27
# Transiently divergent feature detected of SNR 2.18, performing quality cut
# 1.51, 1.56, 1.60
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.44, 1.69, 1.70
# Transiently divergent feature detected of SNR 1.44, performing quality cut
# 1.96, 2.53, 1.50
# Transiently divergent feature detected of SNR 1.96, performing quality cut
# 1.25, 1.23, 1.27
# Transiently divergent feature detected of SNR 1.25, performing quality cut
# 1.58, 1.58, 1.92
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.27, 1.63, 1.79
# Transiently divergent feature detected of SNR 1.27, performing quality cut
# 0.63, 1.04, 1.13
# Transiently divergent feature detected of SNR 0.63, performing quality cut
# 1.05, 2.17, 2.73
# Transiently divergent feature detected of SNR 1.05, performing quality cut
# 0.90, 1.66, 2.06
# Transiently divergent feature detected of SNR 0.90, performing quality cut
# 1.26, 1.81, 1.19
# Transiently divergent feature detected of SNR 1.26, performing quality cut
# 0.95, 1.47, 1.96
# Transiently divergent feature detected of SNR 0.95, performing quality cut
# 1.14, 1.66, 1.75
# Transiently divergent feature detected of SNR 1.14, performing quality cut
# 1.42, 1.75, 1.32
# Transiently divergent feature detected of SNR 1.42, performing quality cut
# 2.06, 1.79, 1.65
# 2.56, 2.24, 2.30
# 1.36, 1.54, 1.65
# Transiently divergent feature detected of SNR 1.36, performing quality cut
# 0.54, 1.11, 1.61
# Transiently divergent feature detected of SNR 0.54, performing quality cut
# 1.57, 2.04, 1.25
# Transiently divergent feature detected of SNR 1.57, performing quality cut
# 2.17, 2.16, 1.12
# 1.59, 1.35, 1.19
# 1.66, 1.31, 1.38
# 1.69, 1.67, 1.45
# 1.33, 2.56, 2.75
# Transiently divergent feature detected of SNR 1.33, performing quality cut
# 0.99, 1.86, 2.28
# Transiently divergent feature detected of SNR 0.99, performing quality cut
# 1.51, 1.31, 1.75
# Transiently divergent feature detected of SNR 1.51, performing quality cut
# 1.83, 2.67, 2.01
# Transiently divergent feature detected of SNR 1.83, performing quality cut
# 1.30, 1.45, 1.86
# Transiently divergent feature detected of SNR 1.30, performing quality cut
# 1.09, 2.22, 2.51
# Transiently divergent feature detected of SNR 1.09, performing quality cut
# 1.29, 1.82, 1.98
# Transiently divergent feature detected of SNR 1.29, performing quality cut
# 1.58, 1.78, 1.21
# Transiently divergent feature detected of SNR 1.58, performing quality cut
# 1.04, 1.50, 1.37
# Transiently divergent feature detected of SNR 1.04, performing quality cut
# 1.43, 1.60, 2.15
# Transiently divergent feature detected of SNR 1.43, performing quality cut
# 1.46, 1.80, 1.98
# Transiently divergent feature detected of SNR 1.46, performing quality cut
# 1.83, 1.65, 1.43
# Event 151124-23:32:55-AI1-ch15-SNR 2.31 Saved
# Event 151124-23:32:59-AI1-ch15-SNR 2.57 Saved
# Event 151124-23:33:00-AI1-ch15-SNR 2.08 Saved
# Event 151124-23:33:06-AI1-ch15-SNR 2.27 Saved
# Event 151124-23:33:13-AI1-ch15-SNR 2.04 Saved
# Event 151124-23:33:14-AI1-ch15-SNR 2.17 Saved
# Event 151124-23:33:18-AI1-ch15-SNR 2.65 Saved
# Event 151124-23:33:20-AI1-ch15-SNR 1.95 Saved
# Event 151124-23:33:20-AI1-ch15-SNR 2.08 Saved
# Event 151124-23:33:23-AI1-ch15-SNR 3.05 Saved
# Event 151124-23:33:24-AI1-ch15-SNR 2.67 Saved
# Event 151124-23:33:25-AI1-ch15-SNR 2.83 Saved
# Event 151124-23:33:30-AI1-ch15-SNR 2.19 Saved
# Event 151124-23:34:02-AI1-ch15-SNR 2.71 Saved
# Event 151124-23:34:13-AI1-ch15-SNR 1.49 Saved
# Event 151124-23:34:36-AI1-ch15-SNR 1.66 Saved
# Event 151124-23:34:54-AI1-ch15-SNR 1.89 Saved
# Event 151124-23:34:55-AI1-ch15-SNR 1.67 Saved
# Event 151124-23:34:56-AI1-ch15-SNR 1.90 Saved
# Event 151124-23:34:57-AI1-ch15-SNR 2.50 Saved
# Event 151124-23:35:09-AI1-ch15-SNR 1.19 Saved
# Event 151124-23:35:10-AI1-ch15-SNR 1.00 Saved
# Event 151124-23:35:40-AI1-ch15-SNR 1.94 Saved
# Event 151124-23:35:42-AI1-ch15-SNR 2.02 Saved
# Event 151124-23:35:58-AI1-ch15-SNR 1.82 Saved
# Event 151124-23:36:03-AI1-ch15-SNR 1.51 Saved
# Event 151124-23:36:10-AI1-ch15-SNR 1.67 Saved
# Event 151124-23:36:18-AI1-ch15-SNR 1.92 Saved
# Event 151124-23:36:19-AI1-ch15-SNR 2.19 Saved
# Event 151124-23:36:20-AI1-ch15-SNR 2.11 Saved
# Event 151124-23:36:21-AI1-ch15-SNR 1.91 Saved
# Event 151124-23:36:27-AI1-ch15-SNR 2.38 Saved
# Event 151124-23:36:40-AI1-ch15-SNR 1.85 Saved
# Event 151124-23:36:50-AI1-ch15-SNR 1.93 Saved
# Event 151124-23:36:57-AI1-ch15-SNR 2.58 Saved
# Event 151124-23:36:57-AI1-ch15-SNR 2.28 Saved
# Event 151124-23:37:03-AI1-ch15-SNR 1.72 Saved
# Event 151124-23:37:14-AI1-ch15-SNR 1.36 Saved
# Event 151124-23:37:15-AI1-ch15-SNR 2.43 Saved
# Event 151124-23:37:15-AI1-ch15-SNR 2.58 Saved
# Event 151124-23:37:21-AI1-ch15-SNR 2.10 Saved
# Event 151124-23:37:33-AI1-ch15-SNR 2.08 Saved
# Event 151124-23:37:34-AI1-ch15-SNR 2.84 Saved
# Event 151124-23:37:35-AI1-ch15-SNR 2.54 Saved
# Event 151124-23:37:36-AI1-ch15-SNR 3.06 Saved
# Event 151124-23:37:52-AI1-ch15-SNR 1.84 Saved
# Event 151124-23:37:59-AI1-ch15-SNR 2.17 Saved
# Event 151124-23:38:00-AI1-ch15-SNR 2.16 Saved
# Event 151124-23:38:00-AI1-ch15-SNR 2.20 Saved
# Event 151124-23:38:02-AI1-ch15-SNR 1.71 Saved
# Event 151124-23:38:08-AI1-ch15-SNR 1.95 Saved
# Event 151124-23:38:09-AI1-ch15-SNR 1.97 Saved
# Event 151124-23:38:17-AI1-ch15-SNR 1.88 Saved
# Event 151124-23:38:18-AI1-ch15-SNR 1.63 Saved
# Event 151124-23:38:29-AI1-ch15-SNR 1.59 Saved
# Event 151124-23:38:35-AI1-ch15-SNR 2.48 Saved
# Event 151124-23:38:36-AI1-ch15-SNR 1.93 Saved
# Event 151124-23:38:37-AI1-ch15-SNR 1.93 Saved
# Event 151124-23:38:45-AI1-ch15-SNR 1.48 Saved
# Event 151124-23:39:31-AI1-ch15-SNR 1.68 Saved
# Event 151124-23:39:36-AI1-ch15-SNR 1.84 Saved
# Event 151124-23:39:37-AI1-ch15-SNR 2.23 Saved
# Event 151124-23:39:41-AI1-ch15-SNR 2.43 Saved
# Event 151124-23:39:56-AI1-ch15-SNR 1.99 Saved
# Event 151124-23:40:03-AI1-ch15-SNR 2.14 Saved
# Event 151124-23:40:05-AI1-ch15-SNR 1.95 Saved
# Event 151124-23:40:12-AI1-ch15-SNR 1.98 Saved
# Event 151124-23:40:13-AI1-ch15-SNR 1.98 Saved
# Event 151124-23:40:21-AI1-ch15-SNR 2.32 Saved
# Event 151124-23:40:40-AI1-ch15-SNR 1.68 Saved
# Event 151124-23:40:41-AI1-ch15-SNR 1.92 Saved
# Event 151124-23:41:21-AI1-ch15-SNR 2.79 Saved
# Event 151124-23:41:25-AI1-ch15-SNR 1.81 Saved
# Event 151124-23:41:26-AI1-ch15-SNR 1.71 Saved
# Event 151124-23:41:26-AI1-ch15-SNR 1.69 Saved
# Event 151124-23:41:27-AI1-ch15-SNR 1.45 Saved
# Event 151124-23:41:50-AI1-ch15-SNR 2.06 Saved
# Event 151124-23:42:28-AI1-ch15-SNR 1.76 Saved
# Event 151124-23:42:30-AI1-ch15-SNR 2.01 Saved
# Event 151124-23:42:35-AI1-ch15-SNR 1.83 Saved
# Event 151124-23:42:38-AI1-ch15-SNR 2.40 Saved
# Event 151124-23:42:38-AI1-ch15-SNR 2.41 Saved
# Event 151124-23:42:41-AI1-ch15-SNR 2.21 Saved
# Event 151124-23:42:42-AI1-ch15-SNR 2.37 Saved
# Event 151124-23:43:02-AI1-ch15-SNR 1.46 Saved
# Event 151124-23:43:03-AI1-ch15-SNR 1.72 Saved
# Event 151124-23:43:13-AI1-ch15-SNR 1.48 Saved
# Event 151124-23:43:56-AI1-ch15-SNR 2.01 Saved
# Event 151124-23:44:00-AI1-ch15-SNR 2.24 Saved
# Event 151124-23:44:30-AI1-ch15-SNR 1.48 Saved
# Event 151124-23:44:32-AI1-ch15-SNR 1.82 Saved
# Event 151124-23:44:54-AI1-ch15-SNR 2.89 Saved
# Event 151124-23:44:55-AI1-ch15-SNR 2.74 Saved
# Event 151124-23:45:04-AI1-ch15-SNR 1.76 Saved
# Event 151124-23:45:09-AI1-ch15-SNR 2.26 Saved
# Event 151124-23:45:11-AI1-ch15-SNR 1.85 Saved
# Event 151124-23:45:17-AI1-ch15-SNR 2.00 Saved
# Event 151124-23:45:21-AI1-ch15-SNR 2.41 Saved
# Event 151124-23:45:22-AI1-ch15-SNR 2.55 Saved
# Event 151124-23:45:30-AI1-ch15-SNR 1.69 Saved
# Event 151124-23:45:44-AI1-ch15-SNR 2.44 Saved
# Event 151124-23:45:52-AI1-ch15-SNR 1.72 Saved
# Event 151124-23:45:55-AI1-ch15-SNR 2.00 Saved
# Event 151124-23:45:56-AI1-ch15-SNR 1.79 Saved
# Event 151124-23:46:26-AI1-ch15-SNR 2.24 Saved
# Event 151124-23:46:49-AI1-ch15-SNR 1.92 Saved
# Event 151124-23:47:14-AI1-ch15-SNR 2.10 Saved
# Event 151124-23:47:16-AI1-ch15-SNR 2.12 Saved
# Event 151124-23:47:17-AI1-ch15-SNR 2.15 Saved
# Event 151124-23:47:18-AI1-ch15-SNR 3.37 Saved
# Event 151124-23:47:25-AI1-ch15-SNR 1.78 Saved
# Event 151124-23:47:30-AI1-ch15-SNR 2.11 Saved
# Event 151124-23:47:30-AI1-ch15-SNR 1.93 Saved
# Event 151124-23:47:31-AI1-ch15-SNR 1.69 Saved
# Event 151124-23:47:36-AI1-ch15-SNR 2.06 Saved
# Event 151124-23:47:39-AI1-ch15-SNR 2.69 Saved
# Event 151124-23:47:41-AI1-ch15-SNR 1.47 Saved
# Event 151124-23:47:48-AI1-ch15-SNR 1.92 Saved
# Event 151124-23:47:59-AI1-ch15-SNR 1.74 Saved
# Event 151124-23:48:10-AI1-ch15-SNR 2.50 Saved
# Event 151124-23:48:10-AI1-ch15-SNR 1.65 Saved
# Event 151124-23:48:11-AI1-ch15-SNR 2.16 Saved
# Event 151124-23:48:48-AI1-ch15-SNR 1.65 Saved
# Event 151124-23:48:49-AI1-ch15-SNR 2.08 Saved
# Event 151124-23:48:50-AI1-ch15-SNR 2.22 Saved
# Event 151124-23:48:56-AI1-ch15-SNR 1.40 Saved
# Event 151124-23:49:01-AI1-ch15-SNR 1.87 Saved
# Event 151124-23:49:27-AI1-ch15-SNR 2.54 Saved
# Event 151124-23:49:30-AI1-ch15-SNR 2.38 Saved
# Event 151124-23:49:34-AI1-ch15-SNR 1.74 Saved
# Event 151124-23:49:34-AI1-ch15-SNR 1.93 Saved
# Event 151124-23:49:40-AI1-ch15-SNR 1.92 Saved
# Event 151124-23:49:56-AI1-ch15-SNR 2.47 Saved
# Event 151124-23:49:57-AI1-ch15-SNR 2.07 Saved
# Event 151124-23:50:20-AI1-ch15-SNR 1.80 Saved
# Event 151124-23:50:20-AI1-ch15-SNR 1.60 Saved
# Event 151124-23:50:34-AI1-ch15-SNR 1.81 Saved
# Event 151124-23:50:35-AI1-ch15-SNR 2.35 Saved
# Event 151124-23:50:45-AI1-ch15-SNR 2.20 Saved
# Event 151124-23:50:45-AI1-ch15-SNR 2.98 Saved
# Event 151124-23:50:48-AI1-ch15-SNR 1.57 Saved
# Event 151124-23:51:17-AI1-ch15-SNR 1.64 Saved
# Event 151124-23:51:19-AI1-ch15-SNR 2.38 Saved
# Event 151124-23:51:20-AI1-ch15-SNR 1.78 Saved
# Event 151124-23:51:29-AI1-ch15-SNR 2.19 Saved
# Event 151124-23:51:30-AI1-ch15-SNR 1.72 Saved
# Event 151124-23:51:35-AI1-ch15-SNR 1.96 Saved
# Event 151124-23:51:35-AI1-ch15-SNR 1.25 Saved
# Event 151124-23:51:51-AI1-ch15-SNR 2.65 Saved
# Event 151124-23:51:52-AI1-ch15-SNR 2.23 Saved
# Event 151124-23:51:52-AI1-ch15-SNR 2.98 Saved
# Event 151124-23:51:53-AI1-ch15-SNR 2.86 Saved
# Event 151124-23:51:58-AI1-ch15-SNR 1.91 Saved
# Event 151124-23:51:59-AI1-ch15-SNR 1.85 Saved
# Event 151124-23:52:31-AI1-ch15-SNR 1.26 Saved
# Event 151124-23:52:42-AI1-ch15-SNR 1.31 Saved
# Event 151124-23:52:53-AI1-ch15-SNR 1.50 Saved
# Event 151124-23:52:54-AI1-ch15-SNR 2.28 Saved
# Event 151124-23:52:58-AI1-ch15-SNR 2.40 Saved
# Event 151124-23:52:58-AI1-ch15-SNR 2.49 Saved
# Event 151124-23:52:59-AI1-ch15-SNR 2.65 Saved
# Event 151124-23:53:04-AI1-ch15-SNR 2.12 Saved
# Event 151124-23:53:04-AI1-ch15-SNR 2.08 Saved
# Event 151124-23:53:07-AI1-ch15-SNR 1.89 Saved
# Event 151124-23:53:18-AI1-ch15-SNR 1.57 Saved
# Event 151124-23:53:22-AI1-ch15-SNR 1.23 Saved
# Event 151124-23:53:31-AI1-ch15-SNR 1.77 Saved
# Event 151124-23:53:34-AI1-ch15-SNR 2.13 Saved
# Event 151124-23:53:36-AI1-ch15-SNR 2.56 Saved
# Event 151124-23:53:38-AI1-ch15-SNR 2.28 Saved
# Event 151124-23:53:55-AI1-ch15-SNR 1.72 Saved
# Event 151124-23:53:58-AI1-ch15-SNR 2.06 Saved
# Event 151124-23:54:00-AI1-ch15-SNR 2.03 Saved
# Event 151124-23:54:19-AI1-ch15-SNR 2.05 Saved
# Event 151124-23:54:20-AI1-ch15-SNR 2.35 Saved
# Event 151124-23:54:38-AI1-ch15-SNR 1.80 Saved
# Event 151124-23:54:42-AI1-ch15-SNR 1.96 Saved
# Event 151124-23:54:50-AI1-ch15-SNR 1.80 Saved
# Event 151124-23:54:52-AI1-ch15-SNR 0.99 Saved
# Event 151124-23:54:56-AI1-ch15-SNR 2.27 Saved
# Event 151124-23:55:26-AI1-ch15-SNR 2.06 Saved
# Event 151124-23:55:27-AI1-ch15-SNR 2.56 Saved
# Event 151124-23:55:32-AI1-ch15-SNR 2.17 Saved
# Event 151124-23:55:33-AI1-ch15-SNR 1.59 Saved
# Event 151124-23:55:33-AI1-ch15-SNR 1.66 Saved
# Event 151124-23:55:35-AI1-ch15-SNR 1.69 Saved
# Event 151124-23:55:49-AI1-ch15-SNR 1.83 Saved

# %%
plt.hist(SNR[0,0], bins=100, label= 'SNR', density=True)
#plt.hist(np.abs(filtered_strain[0,0]), bins=100, label = ' u filtered rms', density=True)
plt.yscale('log')
plt.xlabel('SNR')
plt.ylabel('Density of counts')
plt.legend()
